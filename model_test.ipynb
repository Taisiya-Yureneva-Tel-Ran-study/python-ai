# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt
model = YOLO("runs/detect/train/weights/best.pt")
results = model("test-test.png") 
annotated = results[0].plot()
plt.imshow(annotated)
plt.show()
# Out:
# image 1/1 c:\Users\Taisiya\Documents\study\telRan\python-ai\test4.png: 192x256 51 circles, 60.2ms
# Speed: 0.4ms preprocess, 60.2ms inference, 5.4ms postprocess per image at shape (1, 3, 192, 256)
