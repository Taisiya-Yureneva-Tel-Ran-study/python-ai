# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt
model = YOLO("runs/detect/train4/weights/best.pt")
results = model("datasets/images/val/rect_2.png")
annotated = results[0].plot()
plt.imshow(annotated)
plt.show()
# Out:
# image 1/1 c:\Users\Taisiya\Documents\study\telRan\python-ai\datasets\images\val\rect_2.png: 256x256 2 circles, 1 rect, 40.8ms
# Speed: 0.5ms preprocess, 40.8ms inference, 1.3ms postprocess per image at shape (1, 3, 256, 256)
