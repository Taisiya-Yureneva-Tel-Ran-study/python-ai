# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
import joblib
import converter

# %%
model = joblib.load('gender-model-color.joblib')
df = pd.read_csv('car_sales_cleaned1.csv')
mapper = converter.columnsMapper(['Gender', 'Model', 'Color'], df)
predictions = model.predict([[mapper['Gender']['Male'], mapper['Color']['Red']]]) 
predictions
# Out:
# C:\Users\Taisiya\miniconda3\envs\ai_env\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['Jetta'], dtype=object)
